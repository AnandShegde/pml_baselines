# %% [markdown]
# <a href="https://colab.research.google.com/github/AnandShegde/pml_baselines/blob/main/RStanColab/RStan_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N<-100
Y<-rnorm(N,1.6,0.2)
hist(Y)
# Out:
# Plot with title “Histogram of Y”

# %%
Sys.setenv(PATH= paste("/conda/bin" , Sys.getenv("PATH"), sep = ":" ) )
install.packages('ggmap', repos='http://cran.rstudio.com/')

install.packages('codetools', repos='http://cran.rstudio.com/')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sp’, ‘Rcpp’, ‘RgoogleMaps’, ‘png’, ‘plyr’, ‘rjson’, ‘jpeg’, ‘bitops’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
Sys.setenv(MAKEFLAGS= paste0("-j",parallel::detectCores()))
# after that we'll install rstan in R folder on the Google server (see lib parameter)
install.packages("rstan", dependencies = T, repos = "https://cloud.r-project.org", lib = "/usr/lib/R/library",)
# Out:
# also installing the dependencies ‘lazyeval’, ‘numDeriv’, ‘httpuv’, ‘fontawesome’, ‘sourcetools’, ‘later’, ‘promises’, ‘htmlwidgets’, ‘miniUI’, ‘crosstalk’, ‘zoo’, ‘igraph’, ‘abind’, ‘tensorA’, ‘distributional’, ‘checkmate’, ‘matrixStats’, ‘shiny’, ‘colourpicker’, ‘DT’, ‘dygraphs’, ‘gtools’, ‘markdown’, ‘reshape2’, ‘shinyjs’, ‘shinythemes’, ‘threejs’, ‘xtable’, ‘xts’, ‘ggridges’, ‘posterior’, ‘StanHeaders’, ‘inline’, ‘gridExtra’, ‘RcppParallel’, ‘loo’, ‘RcppEigen’, ‘BH’, ‘RUnit’, ‘shinystan’, ‘bayesplot’, ‘rstantools’, ‘V8’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(rstan)
model<-stan_model("/content/RStan/CoinToss.stan")

# %%
n <- 1000
theta<-0.4
y <- rbinom(n,size=1,prob=theta)
hist(y)

yhat<-mean(y)
alpha0 <- 10
beta0 <- 15
alpha_n<-sum(y)+alpha0
beta_n<-n-sum(y)+beta0

x = seq(0, 1, 1 / 1000)
f_y1 <- dbeta(x, shape1 = alpha0, shape2 = beta0)
f_y2 <- dbeta(x, shape1 = alpha_n, shape2 = beta_n)
# Out:
# Plot with title “Histogram of y”

# %%
fit2<-vb(model,data=list(n=n,y=y,alpha0=alpha0,beta0=beta0))
# Out:
# Chain 1: ------------------------------------------------------------
# Chain 1: EXPERIMENTAL ALGORITHM:
# Chain 1:   This procedure has not been thoroughly tested and may be unstable
# Chain 1:   or buggy. The interface is subject to change.
# Chain 1: ------------------------------------------------------------
# Chain 1:
# Chain 1:
# Chain 1:
# Chain 1: Gradient evaluation took 1.2e-05 seconds
# Chain 1: 1000 transitions using 10 leapfrog steps per transition would take 0.12 seconds.
# Chain 1: Adjust your expectations accordingly!
# Chain 1:
# Chain 1:
# Chain 1: Begin eta adaptation.
# Chain 1: Iteration:   1 / 250 [  0%]  (Adaptation)
# Chain 1: Iteration:  50 / 250 [ 20%]  (Adaptation)
# Chain 1: Iteration: 100 / 250 [ 40%]  (Adaptation)
# Chain 1: Iteration: 150 / 250 [ 60%]  (Adaptation)
# Chain 1: Iteration: 200 / 250 [ 80%]  (Adaptation)
# Chain 1: Success! Found best value [eta = 1] earlier than expected.
# Chain 1:
# Chain 1: Begin stochastic gradient ascent.
# Chain 1:   iter             ELBO   delta_ELBO_mean   delta_ELBO_med   notes
# Chain 1:    100         -678.240             1.000            1.000
# Chain 1:    200         -677.918             0.500            1.000
# Chain 1:    300         -677.267             0.334            0.001   MEDIAN ELBO CONVERGED
# Chain 1:
# Chain 1: Drawing a sample of size 1000 from the approximate posterior...
# Chain 1: COMPLETED.

# %%
fit<-sampling(model,list(n=n,y=y,alpha0=alpha0,beta0=beta0),iter=1500,chains=8,warmup=500)
print(fit)
# Out:
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 1).
# Chain 1:
# Chain 1: Gradient evaluation took 1.1e-05 seconds
# Chain 1: 1000 transitions using 10 leapfrog steps per transition would take 0.11 seconds.
# Chain 1: Adjust your expectations accordingly!
# Chain 1:
# Chain 1:
# Chain 1: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 1: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 1: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 1: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 1: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 1: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 1: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 1: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 1: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 1: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 1: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 1: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 1:
# Chain 1:  Elapsed Time: 0.007251 seconds (Warm-up)
# Chain 1:                0.012283 seconds (Sampling)
# Chain 1:                0.019534 seconds (Total)
# Chain 1:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 2).
# Chain 2:
# Chain 2: Gradient evaluation took 6e-06 seconds
# Chain 2: 1000 transitions using 10 leapfrog steps per transition would take 0.06 seconds.
# Chain 2: Adjust your expectations accordingly!
# Chain 2:
# Chain 2:
# Chain 2: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 2: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 2: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 2: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 2: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 2: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 2: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 2: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 2: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 2: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 2: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 2: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 2:
# Chain 2:  Elapsed Time: 0.007198 seconds (Warm-up)
# Chain 2:                0.012819 seconds (Sampling)
# Chain 2:                0.020017 seconds (Total)
# Chain 2:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 3).
# Chain 3:
# Chain 3: Gradient evaluation took 7e-06 seconds
# Chain 3: 1000 transitions using 10 leapfrog steps per transition would take 0.07 seconds.
# Chain 3: Adjust your expectations accordingly!
# Chain 3:
# Chain 3:
# Chain 3: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 3: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 3: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 3: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 3: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 3: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 3: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 3: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 3: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 3: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 3: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 3: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 3:
# Chain 3:  Elapsed Time: 0.006945 seconds (Warm-up)
# Chain 3:                0.01135 seconds (Sampling)
# Chain 3:                0.018295 seconds (Total)
# Chain 3:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 4).
# Chain 4:
# Chain 4: Gradient evaluation took 8e-06 seconds
# Chain 4: 1000 transitions using 10 leapfrog steps per transition would take 0.08 seconds.
# Chain 4: Adjust your expectations accordingly!
# Chain 4:
# Chain 4:
# Chain 4: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 4: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 4: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 4: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 4: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 4: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 4: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 4: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 4: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 4: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 4: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 4: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 4:
# Chain 4:  Elapsed Time: 0.00721 seconds (Warm-up)
# Chain 4:                0.012556 seconds (Sampling)
# Chain 4:                0.019766 seconds (Total)
# Chain 4:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 5).
# Chain 5:
# Chain 5: Gradient evaluation took 8e-06 seconds
# Chain 5: 1000 transitions using 10 leapfrog steps per transition would take 0.08 seconds.
# Chain 5: Adjust your expectations accordingly!
# Chain 5:
# Chain 5:
# Chain 5: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 5: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 5: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 5: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 5: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 5: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 5: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 5: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 5: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 5: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 5: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 5: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 5:
# Chain 5:  Elapsed Time: 0.00714 seconds (Warm-up)
# Chain 5:                0.012231 seconds (Sampling)
# Chain 5:                0.019371 seconds (Total)
# Chain 5:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 6).
# Chain 6:
# Chain 6: Gradient evaluation took 9e-06 seconds
# Chain 6: 1000 transitions using 10 leapfrog steps per transition would take 0.09 seconds.
# Chain 6: Adjust your expectations accordingly!
# Chain 6:
# Chain 6:
# Chain 6: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 6: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 6: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 6: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 6: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 6: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 6: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 6: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 6: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 6: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 6: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 6: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 6:
# Chain 6:  Elapsed Time: 0.006942 seconds (Warm-up)
# Chain 6:                0.01206 seconds (Sampling)
# Chain 6:                0.019002 seconds (Total)
# Chain 6:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 7).
# Chain 7:
# Chain 7: Gradient evaluation took 8e-06 seconds
# Chain 7: 1000 transitions using 10 leapfrog steps per transition would take 0.08 seconds.
# Chain 7: Adjust your expectations accordingly!
# Chain 7:
# Chain 7:
# Chain 7: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 7: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 7: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 7: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 7: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 7: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 7: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 7: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 7: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 7: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 7: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 7: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 7:
# Chain 7:  Elapsed Time: 0.007122 seconds (Warm-up)
# Chain 7:                0.01265 seconds (Sampling)
# Chain 7:                0.019772 seconds (Total)
# Chain 7:
#
# SAMPLING FOR MODEL 'CoinToss' NOW (CHAIN 8).
# Chain 8:
# Chain 8: Gradient evaluation took 8e-06 seconds
# Chain 8: 1000 transitions using 10 leapfrog steps per transition would take 0.08 seconds.
# Chain 8: Adjust your expectations accordingly!
# Chain 8:
# Chain 8:
# Chain 8: Iteration:    1 / 1500 [  0%]  (Warmup)
# Chain 8: Iteration:  150 / 1500 [ 10%]  (Warmup)
# Chain 8: Iteration:  300 / 1500 [ 20%]  (Warmup)
# Chain 8: Iteration:  450 / 1500 [ 30%]  (Warmup)
# Chain 8: Iteration:  501 / 1500 [ 33%]  (Sampling)
# Chain 8: Iteration:  650 / 1500 [ 43%]  (Sampling)
# Chain 8: Iteration:  800 / 1500 [ 53%]  (Sampling)
# Chain 8: Iteration:  950 / 1500 [ 63%]  (Sampling)
# Chain 8: Iteration: 1100 / 1500 [ 73%]  (Sampling)
# Chain 8: Iteration: 1250 / 1500 [ 83%]  (Sampling)
# Chain 8: Iteration: 1400 / 1500 [ 93%]  (Sampling)
# Chain 8: Iteration: 1500 / 1500 [100%]  (Sampling)
# Chain 8:
# Chain 8:  Elapsed Time: 0.007072 seconds (Warm-up)
# Chain 8:                0.012455 seconds (Sampling)
# Chain 8:                0.019527 seconds (Total)
# Chain 8:
# Inference for Stan model: CoinToss.
# 8 chains, each with iter=1500; warmup=500; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=8000.
#
#          mean se_mean   sd    2.5%     25%     50%     75%   97.5% n_eff Rhat
# theta    0.41    0.00 0.02    0.38    0.40    0.41    0.42    0.44  2796    1
# lp__  -692.71    0.01 0.71 -694.70 -692.87 -692.44 -692.25 -692.20  3994    1
#
# Samples were drawn using NUTS(diag_e) at Sun Jun 12 16:52:59 2022.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
params=extract(fit)
params2=extract(fit2)
plot(density(params$theta),main="Prior & Posterior distributions",type = "l",col="red",xlab = expression(theta), ylab = "pdf",xlim=c(0,1),lwd=3,ylim=c(0,28))
lines(density(params2$theta),col="blue",lwd=3)
lines(x,f_y2,col="black",lwd=3,lty=3)
lines(x,f_y1,type="l",col="green",lwd=3)
legend("topright", c("HMC","Vi","Posterior","Prior"), lwd = 3, col = c("red","blue","black","green"))
# Out:
# Plot with title “Prior & Posterior distributions”

# %%
params=extract(fit)
params2=extract(fit2)
plot(density(params$theta),main="Prior & Posterior distributions",type = "l",col="red",xlab = expression(theta), ylab = "pdf",xlim=c(0.35,0.5),lwd=3,ylim=c(0,28))
lines(density(params2$theta),col="blue",lwd=3)
lines(x,f_y2,col="black",lwd=3,lty=3)
lines(x,f_y1,type="l",col="green",lwd=3)
legend("topright", c("HMC","Vi","Posterior","Prior"), lwd = 3, col = c("red","blue","black","green"))
# Out:
# Plot with title “Prior & Posterior distributions”
